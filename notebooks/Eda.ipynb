# %%
import pandas as pd

# %%
nifty50_all_data = pd.read_csv("E:\\My Projects\\Stock price prediction\\Data set\\NIFTY50_all.csv")

# %%
nifty50_all_data
# Out:
#               Date      Symbol Series  Prev Close    Open     High     Low  \
# 0       2007-11-27  MUNDRAPORT     EQ      440.00  770.00  1050.00  770.00
# 1       2007-11-28  MUNDRAPORT     EQ      962.90  984.00   990.00  874.00
# 2       2007-11-29  MUNDRAPORT     EQ      893.90  909.00   914.75  841.00
# 3       2007-11-30  MUNDRAPORT     EQ      884.20  890.00   958.00  890.00
# 4       2007-12-03  MUNDRAPORT     EQ      921.55  939.75   995.00  922.00
# ...            ...         ...    ...         ...     ...      ...     ...
# 235187  2021-04-26        ZEEL     EQ      188.00  190.60   191.10  185.10
# 235188  2021-04-27        ZEEL     EQ      186.40  188.00   192.95  186.80
# 235189  2021-04-28        ZEEL     EQ      188.15  188.80   190.60  187.10
# 235190  2021-04-29        ZEEL     EQ      189.10  190.80   191.65  186.00
# 235191  2021-04-30        ZEEL     EQ      186.55  185.30   190.95  183.65
#
#           Last   Close    VWAP    Volume      Turnover   Trades  \
# ...

# %% [markdown]
# 1.How many rows and columns are present in the dataset?

# %%
print("Total columns = ",nifty50_all_data.shape[1])
print("Total rows = ",nifty50_all_data.shape[0])
# Out:
# Total columns =  15
# Total rows =  235192

# %% [markdown]
# 2.What are the data types of each column?

# %%
nifty50_all_data.dtypes
# Out:
# Date                   object
# Symbol                 object
# Series                 object
# Prev Close            float64
# Open                  float64
# High                  float64
# Low                   float64
# Last                  float64
# Close                 float64
# VWAP                  float64
# Volume                  int64
# Turnover              float64
# Trades                float64
# Deliverable Volume    float64
# %Deliverble           float64
# dtype: object

# %% [markdown]
# 3.How many unique stock symbols are available?

# %%
uniqueSymbols = nifty50_all_data["Symbol"].unique()

print("<-----Unique symbols name----->")
for val in uniqueSymbols:
    print(val,end=' , ')
# Out:
# <-----Unique symbols name----->
# MUNDRAPORT , ADANIPORTS , ASIANPAINT , UTIBANK , AXISBANK , BAJAJ-AUTO , BAJAJFINSV , BAJAUTOFIN , BAJFINANCE , BHARTI , BHARTIARTL , BPCL , BRITANNIA , CIPLA , COALINDIA , DRREDDY , EICHERMOT , GAIL , GRASIM , HCLTECH , HDFC , HDFCBANK , HEROHONDA , HEROMOTOCO , HINDALC0 , HINDALCO , HINDLEVER , HINDUNILVR , ICICIBANK , INDUSINDBK , INFOSYSTCH , INFY , IOC , ITC , JSWSTL , JSWSTEEL , KOTAKMAH , KOTAKBANK , LT , M&M , MARUTI , NESTLEIND , NTPC , ONGC , POWERGRID , RELIANCE , SBIN , SHREECEM , SUNPHARMA , TELCO , TATAMOTORS , TISCO , TATASTEEL , TCS , TECHM , TITAN , ULTRACEMCO , UNIPHOS , UPL , SESAGOA , SSLT , VEDL , WIPRO , ZEETELE , ZEEL ,

# %% [markdown]
# 4.What is the date range of the dataset (earliest and latest date)?

# %%
nifty50_all_data.groupby('Symbol')["Date"].agg(earliest_date = "min" , latest_date = "max")
# Out:
#            earliest_date latest_date
# Symbol
# ADANIPORTS    2012-01-17  2021-04-30
# ASIANPAINT    2000-01-03  2021-04-30
# AXISBANK      2007-08-16  2021-04-30
# BAJAJ-AUTO    2008-05-26  2021-04-30
# BAJAJFINSV    2008-05-26  2021-04-30
# ...                  ...         ...
# UTIBANK       2000-01-03  2007-08-14
# VEDL          2015-05-07  2021-04-30
# WIPRO         2000-01-03  2021-04-30
# ZEEL          2007-02-28  2021-04-30
# ZEETELE       2000-01-03  2007-02-27
#
# [65 rows x 2 columns]

# %% [markdown]
# 5.How many missing values are present in each column?

# %%
nifty50_all_data.isnull().sum()
# Out:
# Date                       0
# Symbol                     0
# Series                     0
# Prev Close                 0
# Open                       0
# High                       0
# Low                        0
# Last                       0
# Close                      0
# VWAP                       0
# Volume                     0
# Turnover                   0
# Trades                114848
# Deliverable Volume     16077
# %Deliverble            16077
# dtype: int64

# %% [markdown]
# 6.Are there any negative values in numerical columns?

# %%
numeric = nifty50_all_data.select_dtypes(include="number")

negative = (numeric < 0).sum()

print(negative)
# Out:
# Prev Close            0
# Open                  0
# High                  0
# Low                   0
# Last                  0
# Close                 0
# VWAP                  0
# Volume                0
# Turnover              0
# Trades                0
# Deliverable Volume    0
# %Deliverble           0
# dtype: int64

# %% [markdown]
# 7. What are the mean, median, minimum, maximum, and standard deviation of each numerical column?

# %%
nifty50_all_data.describe()
# Out:
#           Prev Close           Open           High            Low  \
# count  235192.000000  235192.000000  235192.000000  235192.000000
# mean     1266.196349    1267.759708    1286.581440    1247.488465
# std      2581.370320    2585.259609    2619.649216    2546.621396
# min         0.000000       8.500000       9.750000       8.500000
# 25%       274.300000     275.000000     279.500000     269.600000
# 50%       566.500000     567.025000     576.900000     556.500000
# 75%      1242.200000    1243.312500    1263.000000    1221.650000
# max     32861.950000   33399.950000   33480.000000   32468.100000
#
#                 Last          Close          VWAP        Volume      Turnover  \
# count  235192.000000  235192.000000  235192.00000  2.351920e+05  2.351920e+05
# mean     1266.388302    1266.554351    1267.13230  3.045903e+06  1.610138e+14
# std      2581.392543    2582.140942    2582.69998  7.333981e+06  3.298085e+14
# ...

# %% [markdown]
# 8. Number of records for each stock

# %%
nifty50_all_data["Symbol"].value_counts()
# Out:
# Symbol
# ASIANPAINT    5306
# TITAN         5306
# DRREDDY       5306
# CIPLA         5306
# BPCL          5306
#               ...
# MUNDRAPORT    1023
# TELCO          999
# KOTAKMAH       502
# SSLT           388
# JSWSTL         123
# Name: count, Length: 65, dtype: int64

# %% [markdown]
# 9. Duplicate rows

# %%
print(nifty50_all_data.duplicated().sum())
# Out:
# 0

# %% [markdown]
# 10. how many gap between Open and Close?

# %%
nifty50_all_data["Gap"] = abs(nifty50_all_data["Open"]- nifty50_all_data["Close"])

# %%
nifty50_all_data[["Symbol","Gap"]].groupby("Symbol").max()
# Out:
#                 Gap
# Symbol
# ADANIPORTS    79.55
# ASIANPAINT   251.05
# AXISBANK     130.55
# BAJAJ-AUTO   339.55
# BAJAJFINSV  1018.95
# ...             ...
# UTIBANK       50.05
# VEDL          20.25
# WIPRO       1529.55
# ZEEL         119.35
# ZEETELE      163.45
#
# [65 rows x 1 columns]

# %% [markdown]
# 11. Which stock has the highest delivery percentage?

# %%
nifty50_all_data.groupby("Symbol")["%Deliverble"].max().sort_values(ascending=False)
# Out:
# Symbol
# ASIANPAINT    1.0000
# SUNPHARMA     1.0000
# BAJAJ-AUTO    1.0000
# BAJAJFINSV    1.0000
# BAJAUTOFIN    1.0000
#                ...
# HINDLEVER     0.8571
# UPL           0.8419
# SSLT          0.7407
# TISCO         0.7070
# TELCO         0.6593
# Name: %Deliverble, Length: 65, dtype: float64

# %% [markdown]
# 12.Which stock has the highest closing price?

# %%
nifty50_all_data[["Symbol","Close"]].max()
# Out:
# Symbol     ZEETELE
# Close     32861.95
# dtype: object
